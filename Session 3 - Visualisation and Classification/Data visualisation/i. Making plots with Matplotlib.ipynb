# %% [markdown]
# # Making basic plots with Matplotlib <img src="logo.png",width=140,height=140, align="right">

# %% [markdown]
# Matplotlib is a 2D plotting library that makes it very easy to create a variety of interesting charts.<br>
# These examples show the basics of what Matplotlib can do. It can do so much more. Check out its documentation to see more (http://matplotlib.org/)
#
# Matplotlib only outputs static graphs. This is not necessarily a bad thing, but it you want to show interactive graphs, Plotly is the better option. Nonetheless, matplotlib is the most widely used library for plotting in Python, so it's important to be familiar with it.

# %%
# Render our plots inline, i.e. they will show up in the notebook
# %matplotlib inline

# Import the necessary modules
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Line plots
#
# **Purpose**: Showing trends in data -- usually time series data with many time points.
#
# **matplotlib function**: [`plot(x, y)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot)
#
# * `x`: The x-coordinates of the lines or markers.
#
# * `y`: The y-coordinates of the lines or markers.

# %% [markdown]
# Let's start in the simplest way possible and plot $y=x^2$ in a line graph

# %%
x = np.array([0, 1, 2,3,4])
y=np.exp(x)
plt.plot(x, y, '-', linewidth=3)
;
# Out:
# ''

# %% [markdown]
# Great, that was easy. That was probably the way you've done it before. However, that style of plotting stuff does not follow the typical 'matplotlib workflow'. Let me tell you a bit more about it and why it's good to keep that structure when plotting.
#
# In order to learn how to properly create and tweak graphs, let's break it down in a few steps. There is a matplotlib framework that allows you to create advanced graphs with just a few commands, these steps are:
#
# 1. Start by creating a figure. The figure is basically the axes that are going to contain you data series to be plotted in there. The command to create a new figure in your notebook is **plt.figure()**. You can define figure size here. You will see later on how you can create multiple graphs in one figure. That's why it's good practice to start by defining the figure first, rather than going straight in for the plot.
#
# 2. Plot the data. There can be multiple data series in one plot, for example **plt.plot('x')** and plt.plot('y') will give a line plot of both x and y in the same plot in the figure. (mind you there can also be multiple sub-plots in one figure, each containing multiple data series) You can also do plt.bar(x), to get a different type of plot. The term "plt.plot()" is reserved for normal line plots.
#
# 3. Configure the axes, you might want to add a series as tickmarks for one of the axes. **plt.xticks()** and plt.yticks() allow you to do this, and **plt.xlim()** and plt.ylim() set the range of your axes.
#
# 4. Add annotation. You should consider adding labels and legends to the data series plotted, and a graph title. You can use **plt.xlabel()**, plt.ylabel(), **plt.legend()**, **plt.title()**, and **plt.grid()** to show gridlines etc
#
# 5. Show or save the figure to display the result. You can use **plt.show()** just to show, we won't need this because of our settings above (%matplotlib inline), which causes the figures to be shown within the notebook. **plt.savefig()** allow you to store the figure to a designated folder
#
# So now that we have a framework for using matplotlib, let's give it some practice! Let's return to creating line graphs

# %%
# np.linspace returns num evenly spaced numbers over the specified interval 0-20
x = np.linspace(0, 20)

#numpy contains functions such as sin, cos and exp which are called by np.sin, np.cos etc
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

#Start the figure
plt.figure()

#add two lines
plt.plot(x, y1)
plt.plot(x, y2)

# and done, let's keep it simple
# remember we should use plt.show() but we don't need it because of our settings!
;
# Out:
# ''

# %% [markdown]
# With the plt.plot() command there are a few parameters we can tweak. This is a few of them:
#
# **Commonly used parameters**:
#
# * `color`: Set the color of the line.
#
# * `linestyle`: Set the line style, e.g., solid, dashed, or none.
#
# * `linewidth`: Set the line thickness.
#
# * `marker`: Set the marker style, e.g., circles, triangles, or none.
#
# * `markersize`: Set the marker size.
#
# * `label`: Set the label for the line that will show up in the legend.

# %%
#this is our graph data
x = np.linspace(0, 20)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

# start the figure
plt.figure()

#set a bunch of parameters under the plt.plot() commands
plt.plot(x,
         y1,
         color='black',
         linestyle='-',
         linewidth=2,
         marker='s',
         markersize=6,
         label='y1')

plt.plot(x,
         y2,
         color='gray',
         linestyle='--',
         linewidth=2,
         marker='^',
         markersize=6,
         label='y2')

# and let's add a legend
plt.legend()
# and done
;
# Out:
# ''

# %% [markdown]
# **Exercise:** Let's try creating a linegraph ourselves. I'll give you x and y values, and let's plot x and y in a graph. This time, I'd like you to add a title to the graph, and xlabels and y-labels to the axis (you can call them anything), and if you can, also display a legend (call it anything you want)
#
# If you get stuck, you can check StackOverflow, for example: http://stackoverflow.com/questions/39715601/how-to-create-a-line-chart-using-matplotlib

# %%
x = np.linspace(0, 3*np.pi, num=500)
y = np.sin(x**2)

plt.plot(x, y, label='')
plt.title('Hello World')
plt.xlabel('age')
plt.ylabel('how much i liked my brother')
plt.legend()
# Out:
# /opt/anaconda/envs/Python3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# # Vertical bar charts
#
# Let's move on. We've seen line charts, let's now get real crazy and plot some bar charts. We've actually already seen these a few times in our previous exercises, but let's have a deeper look.
#
# **Purpose**: Comparing categories **OR** showing temporal trends in data with few (< 4) time points.
#
# **matplotlib function**: [`bar(bottom, height)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.bar)
#
# * `bottom`: The x coordinate(s) on the bottom of the bars.
#
# * `height`: The height(s) of the bars.
#
# Alright here we go:

# %%
years = np.arange(2012, 2015)
values = [2, 5, 9]

plt.figure()

plt.bar(years, values)
;
# Out:
# ''

# %% [markdown]
# The x-axis labels 'years looks weird, we'll fix that in a second.
#
# The parameters we can tweak in the plt.bar() function are as follows (remember, before we used plt.plot(), so now we're changing this to a different type)
#
# **Commonly used parameters**:
#
# * `color`: Set the color of the bars.
#
# * `edgecolor`: Set the color of the lines on the edges of the bars.
#
# * `width`: Set the width of the bars.
#
# * `align`: Set the alignment of the bars, e.g., center them on the x coordinate(s).
#
# * `label`: Set the label for the bar that will show up in the legend.
#
# Let's see this in action

# %%
# We'll add another set of values to plot
years = np.arange(2012, 2015)
category1_values = [2, 5, 9]
category2_values = [7, 6, 3]

plt.figure()

# tweak as much as we can under plt.bar()
plt.bar(years - 0.2,
        category1_values,
        color='blue',
        edgecolor='none',
        width=0.4,
        align='center',
        label='y1')

plt.bar(years + 0.2,
        category2_values,
        color='orange',
        edgecolor='none',
        width=0.4,
        align='center',
        label='y2')

# now here comes the trick; we're going to use the "string" version of years for our labels on the x-axis
plt.xticks(years, [str(year) for year in years])

plt.legend()
Wonder;
# Out:
# ''

# %% [markdown]
# Wonderful, that looks much better. We can also plot bar charts on their side, they're called horizontal bar charts...
# And guess what, all we have to do is add an "h", so we're going to write plt.barh() this time
#
# # Horizontal bar charts
#
# **Purpose**: Comparing categories.
#
# **matplotlib function**: [`barh(left, width)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.barh)
#
# * `left`: The y coordinate(s) on the left side of the bars.
#
# * `width`: The width(s) of the bars.
#
# Let's give it  a try:

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 12, 4, 2, 9]

plt.figure()

plt.barh(categories, values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-b05049e75dce> in <module>()
#       4 plt.figure()
#       5
# ----> 6 plt.barh(categories, values)
#
# /Users/charlottewerger/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in barh(bottom, width, height, left, hold, **kwargs)
#    2724                       mplDeprecation)
#    2725     try:
# -> 2726         ret = ax.barh(bottom, width, height=height, left=left, **kwargs)
#    2727     finally:
#    2728         ax._hold = washold
#
# /Users/charlottewerger/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in barh(self, bottom, width, height, left, **kwargs)
#    2289
#    2290         patches = self.bar(left=left, height=height, width=width,
# -> 2291                            bottom=bottom, orientation='horizontal', **kwargs)
#    2292         return patches
#    2293
#
# ...

# %% [markdown]
# Oops, what just happened? Ok, so it turns out that matplotlib does not like it if you give it a bunch of strings and floats, as it does not know how these things relate to each other. Let's try something else:

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 12, 4, 2, 9]

plt.figure()

plt.barh(np.arange(len(categories)), values)
;
# Out:
# ''

# %% [markdown]
# Ok, that's slightly better but still useless. Now I've converted those categories into numerical values, but I don't know what corresponds to what. We need to add some yticks to this to know what's going on.

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 12, 4, 2, 9]

plt.figure()

plt.barh(np.arange(len(categories)), values)

plt.yticks(np.arange(len(categories)),
           ['Category {}'.format(x) for x in categories])
;
# Out:
# ''

# %% [markdown]
# **Exercise:** Can you change the way the bars are arranged in the code above? np.arange(len()) automatically assigns values to the categories based on their length in the series, but if we want A on top and E at the bottom, we need to tweak this. Hint: can you think of a number to multiply with, to change the order np.arange assigns?

# %%
# copy the code from above and play around here

# %% [markdown]
# Here's what we can change in a horizontal bar plot
#
# **Commonly used parameters**:
#
# * `color`: Set the color of the bars.
#
# * `edgecolor`: Set the color of the lines on the edges of the bars.
#
# * `height`: Set the height of the bars.
#
# * `align`: Set the alignment of the bars, e.g., center them on the y coordinate(s).
#
# So let's tweak a few things:

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 12, 4, 2, 9]

plt.figure()

plt.barh(np.arange(len(categories)),
         values,
         color='blue',
         edgecolor='none',
         height=0.6,
         align='center')

plt.yticks(np.arange(len(categories)),
           ['Category {}'.format(x) for x in categories])
;
# Out:
# ''

# %% [markdown]
# So now, let's have a look at my favourite type of chart...pie! Matplotlib can bake great pies, and the best thing is, it's very easy!
#
# # Pie charts
#
# **Purpose**: Displaying a simple proportion.
#
# **matplotlib function**: [`pie(sizes)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie)
#
# * `sizes`: The size of the wedges as either a fraction or number.
#
# Let's start off very simple:

# %%
counts = [17, 14]

plt.figure()

plt.pie(counts)
;
# Out:
# ''

# %% [markdown]
# Wait...what? Oval pies? That's weird.
#
# Well this is because you haven't defined the figure-size to be square, so let's do that. We can give plt.figure() a size parameter, and when it's a square, you're pie will look normal.

# %%
counts = [17, 14]

plt.figure(figsize=(4, 4))

plt.pie(counts)
;
# Out:
# ''

# %% [markdown]
# Much better, let's have a look at what we can tweak.
#
# **Commonly used parameters**:
#
# * `colors`: Set the colors of the wedges.
#
# * `labels`: Set the labels of the wedges.
#
# * `startangle`: Set the angle that the wedges start at.
#
# * `autopct`: Set the percentage display format of the wedges.

# %%
counts = [17, 14]

plt.figure(figsize=(4, 4))

plt.pie(counts,
        colors=['blue', 'orange'],
        labels=['Category A', 'Other categories'],
        startangle=90,
        autopct='%1.1f%%')
;

# %% [markdown]
# **Exercise:** Take the 'categories' and 'values' from the horizontal bar chart exercise above, and create a pie chart.
# Do you notice what happens to the values? Also, do you see how labels and values are connected to each other?

# %%
# Write here

# %% [markdown]
# # Scatter plots
#
# One of the most useful plots are perhaps scatter plots. When exploring your data, and seeing how your features relate to your target variable, you'll be using these a lot.
#
# **Purpose**: Displaying relationships between variables.
#
# **matplotlib function**: [`scatter(x, y)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter)
#
# * `x`, `y`: The values for the two variables.
#
# Let's look at an example

# %%
x = range(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()

plt.scatter(x, y)
;
# Out:
# ''

# %% [markdown]
# We can also tweak this stuff.
#
# **Commonly used parameters**:
#
# * `c`: Set the color of the markers.
#
# * `s`: Set the size of the markers.
#
# * `marker`: Set the marker style, e.g., circles, triangles, or squares.
#
# * `edgecolor`: Set the color of the lines on the edges of the markers.

# %%
x = np.arange(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()

plt.scatter(x,
            y,
            c='red',
            s=40,
            marker='s',
            edgecolor='none')
;
# Out:
# ''

# %% [markdown]
# **Exercise:** Change the area of the markers to 10, and check what happens. You can also play with the marker style, the default is a round point, but see what happens when you set 'marker=d'

# %%
# Copy the code above and play around here to compare

# %% [markdown]
# The area of each point can actually be a very useful thing to play with. It can be a way to introduce another variable to the graph, by allowing the marker size to vary (e.g. big dot for high value on third feature, little dot for low value on that third feature. Let me give you an example on how to do this:

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
# area is the third variable in the graph, and varies from 0 to 15 point radiuses for the circle
area = np.pi *(15 * np.random.rand(N))**2 

plt.figure()
plt.scatter(x, y, s=area, alpha=0.5)
;
# Out:
# ''

# %% [markdown]
# **Exercise:** This is such a beautiful plot, let's save it somewhere as a png file. Can you try using the plt.savefig() command and save it anywhere you like. Also check that it goes to the location where you want it to go to (which is probably somewhere in your SherlockML workspace)

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = np.pi *(15 * np.random.rand(N))**2 

plt.figure()
plt.scatter(x, y, s=area, alpha=0.5)
plt.savefig('beautiful_dots.png', bbox_inches='tight')
;
# Out:
# ''

# %% [markdown]
# The savefig() command has a few options to save your graph in different ways and qualities. You can use the option **bbox_inches='tight'** to make sure your figure size is adjusted to fit your plots and/or subplots into one frame, so you won't be left with empty white space around your plot. You can also use **'tight_layout'** whilst creating the plot to adjust the plots and subplots to fit to the figure size (you'll see an example later). Lastly, you can set the resolution of the graph. If your graph is looking very grainy, you can increase the resolution. The option needs to be given under the savefig command, and is as follows: plt.savefig('name'.png, **dpi=200**). The higher the value you pass into dpi, the better the resolution of your image. This will come in handy when you for example need to zoom

# %% [markdown]
# # Subplots
#
# There is a way to get multiple plots into one figure, which comes in handy when you have to create many different plots. You've already seen these types of plots before in our exercises, so let me show you how to do this.
#
# **Purpose:** Allows you to place multiple charts in a figure.
#
# **matplotlib function:** [``subplot(nrows, ncols, plot_number)``](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.subplot)
#
# * `nrows`: The number of rows in the figure.
#
# * `ncols`: The number of columns in the figure.
#
# * `plot_number`: The placement of the chart (starts at 1, and not at 0 as our arrays, dataframes and series do, confusion alert!).
#
# Let's get started. Remember I talked about tight_layout before? When you're working with many subplots you have to think about how to fit stuff into a page/one graph, so we're going to apply it here.

# %%
plt.figure()

#we need to start a little loop that's going to count from 1 up to but not including 7
for i in range(1, 7):
    #each number will be assigned a place in my 3 by 2 set of graphs 
    plt.subplot(3, 2, i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()
;
# Out:
# ''

# %% [markdown]
# ** Exercise: ** Your turn! Can you create a 3 by 3 set of empty graphs?

# %%
## code here

# %% [markdown]
# Subplots can take any form or shape, and they don't have to be the same as all the other subplots in the figure. I'll show you how to put 2 different types of plots into 1 figure.

# %%
dist1 = np.random.normal(42, 7, 1000)
dist2 = np.random.normal(59, 3, 1000)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(dist1)
plt.title('dist1')

plt.subplot(1, 2, 2)
plt.scatter(dist2, dist1)
plt.xlabel('dist2')
plt.ylabel('dist1')

plt.tight_layout()
;

# %% [markdown]
# As you can see subplots take the same arguments as normal plots do, you can add titles, axis-labels, legends, etc etc.

# %% [markdown]
# Now let's think about how we can repeat the same plot across many different subplots. This is useful for comparing many different categories of the same thing. You could loop over a set of different values and re-create the same plot. Let's start with plotting a set of different time-series data over a year range.

# %%
years = np.arange(2010, 2016)

plt.figure()

for category_num in range(1, 17):
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)

# add range to our y-axis    
plt.ylim(10, 18)
# we've seen this before, add year labels on the x-axis, but use year as string, otherwise we get those funky values
plt.xticks(years, [str(year) for year in years])
;
# Out:
# ''

# %% [markdown]
# From the code above, can you deduce how many lines we have plotted?
#
# To make sure we understand what the loop above does, it sometimes helps to print stuff. So let's print those different series of y_vals that were created in the loop. Have a look:

# %%
for category_num in range(1, 17):
    print(np.arange(10, 16) + (np.random.random(6) * category_num / 4.))
# Out:
# [ 10.15158951  11.18742265  12.01279648  13.18069878  14.03770935
#   15.18587433]
# [ 10.25142744  11.43284304  12.18668217  13.00367628  14.18666167
#   15.37718071]
# [ 10.39213153  11.08868461  12.01414285  13.04384642  14.12718019
#   15.68545799]
# [ 10.99356202  11.53907294  12.66638669  13.47017744  14.82598211
#   15.28256997]
# [ 10.6041284   11.90449968  12.32697986  13.79922836  15.10934865
#   15.98528555]
# [ 10.60816396  11.37926717  12.01845175  13.62872438  14.42263842
#   15.17086787]
# [ 11.36259255  11.57906464  13.29654465  13.17485998  14.03217374
#   16.18261424]
# [ 10.01305627  11.24073528  12.73736549  14.00397247  14.2439724
#   15.57832167]
# [ 12.13561445  11.63505585  13.01608337  13.63842643  16.06314361
#   16.2814384 ]
# [ 10.17187998  11.13355871  12.50703617  13.97761606  15.87579466
#   16.27470247]
# [ 12.72005166  12.8853412   14.30534012  13.06905126  15.7705315
#   16.11878868]
# ...

# %% [markdown]
# Now let's repeat the many lines chart, but this time we're going to use subplots to show each line individually. Notice that this time the set-up for the graph is the same (i.e. each subplot is the same graph, same range, same labels etc) so we can put the creation of the graph inside the loop we used earlier.

# %%
years = np.arange(2010, 2016)

plt.figure(figsize=(10, 10))

#plt.ylim and plt.xticks etc go inside the loop, as we want those settings for each subplot
for category_num in range(1, 17):
    plt.subplot(4, 4, category_num)
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)
    plt.ylim(10, 18)
    plt.xticks(years, [str(year) for year in years])
    plt.title('Category {}'.format(category_num))
    
plt.tight_layout()
;
# Out:
# ''

# %% [markdown]
# ** Exercise:** Using the expressions for x and y given below, can you create for me 8 graphs, whereby you let the value of i range from 1 to 9?

# %%
x = np.arange(20)
y = np.arange(50, 70) + (np.random.random(20) * i)

# create plot here

# %% [markdown]
# # Matplotlib style
#
# There are many ways to change the look of your graphs. There are parameters to play with under the standard configuration of matplotlib, which you can change. You can have a look for example here: http://matplotlib.org/users/customizing.html#dynamic-rc-settings
#
# It is however time consuming to manually set the style configuration whenever you're creating new plots. I would advise you to use some pre-set styles, that are commonly used. Let's first create some data we can graph:

# %%
x1_values = [2012, 2013, 2014, 2015]
y1_values = [4.3, 2.5, 3.5, 4.5]

x2_values = [2012, 2013, 2014, 2015]
y2_values = [2.4, 4.4, 1.8, 2.8]

x3_values = [2012, 2013, 2014, 2015]
y3_values = [2, 2, 3, 5]

# %% [markdown]
# Without having changed anything about the style, let's just have a look at plot for this data

# %%
plt.figure()
plt.plot(x1_values, y1_values, label='London')
plt.plot(x2_values, y2_values, label='Hong Kong')
plt.plot(x3_values, y3_values, label='San Francisco')

plt.xlim(2012, 2015)
plt.ylim(0, 6)
plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
plt.yticks([1, 2, 3, 4, 5])

plt.xlabel('')
plt.ylabel('% increase housing prices')

plt.legend(loc='upper center', ncol=3)
plt.grid(True)

plt.savefig('price_graph.png', dpi=150)

# %% [markdown]
# OK not bad, but can we make it look better? Let me show you first which styles are available:

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn']

# %% [markdown]
# Wow that's a lot. Both gg-plot and the seaborn styles are used quite often actually. The grayscale is one to remember when you know you'll have to output something in black and white. Let's pick one style and set it to the graph similar to above.

# %%
with plt.style.context('seaborn-white'):
    plt.plot(x1_values, y1_values, label='London')
    plt.plot(x2_values, y2_values, label='Hong Kong')
    plt.plot(x3_values, y3_values, label='San Francisco')

    plt.xlim(2012, 2015)
    plt.ylim(0, 6)
    plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
    plt.yticks([1, 2, 3, 4, 5])

    plt.xlabel('')
    plt.ylabel('% increase housing prices')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

    plt.savefig('pretty_graph.png', dpi=150)

# %% [markdown]
# **Exercise:** Change the style of the graph, picking from one of the styles available and see what it does. Do you have a favorite?

# %% [markdown]
# A way to change the style of all the graphs in the entire notebook, is to start the notebook and tell matplotlib to use a certain style every time. The command to do is as follows:

# %%
# Use this command at the beginning of your notebook to fix the style throughout
plt.style.use('seaborn-white')

# %% [markdown]
# If you are interested in learning more about customizing your graph styles, have a read here:
#
# http://matplotlib.org/users/style_sheets.html

# %% [markdown]
# # Answers to the exercises

# %% [markdown]
# **Exercise:** Let's try creating a linegraph ourselves. I'll give you x and y values, and let's plot x and y in a graph. This time, I'd like you to add a title to the graph, and xlabels and y-labels to the axis (you can call them anything), and if you can, also display a legend (call it anything you want)

# %%
x = np.linspace(0, 3*np.pi, num=500)
y = np.sin(x**2)

plt.figure()
plt.plot(x, y)

plt.title('A wonderful line chart')
plt.xlabel('x-values', fontsize=15)
plt.ylabel('y-values', fontsize=15)
plt.legend(['Squiggle'])
;
# Out:
# ''

# %% [markdown]
# **Exercise:** Can you change the way the bars are arranged in the code above? np.arange(len()) automatically assigns values to the categories based on their length in the series, but if we want A on top and E at the bottom, we need to tweak this. Hint: can you think of a number to multiply with, to change the order np.arange assigns?

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 12, 4, 2, 9]

plt.figure()

plt.barh(-np.arange(len(categories)), values)

plt.yticks(-np.arange(len(categories)),
           ['Category {}'.format(x) for x in categories])
;
# Out:
# ''

# %% [markdown]
# **Exercise:** Take the 'categories' and 'values' from the horizontal bar chart exercise above, and create a pie chart.
# Do you notice what happens to the values? Also, do you see how labels and values are connected to each other?

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 12, 4, 2, 9]

plt.figure(figsize=(4, 4))

plt.pie(values,
        colors=['blue', 'orange', 'red', 'yellow', 'green'],
        labels=categories,
        startangle=90,
        autopct='%1.1f%%')
;

# Values become percentages of total. Categories and values are connected purely by the order of in the series, 
# so A goes to 7, B goes to 12, etc, i.e. ordering is very important when linking labels to values in charts!
# Out:
# ''

# %% [markdown]
# ** Exercise: ** Your turn! Can you create a 3 by 3 set of empty graphs?

# %%
plt.figure()

for i in range(1, 10):
    plt.subplot(3, 3, i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()
;

# %% [markdown]
# ** Exercise:** Using the expressions for x and y given below, can you create for me 8 graphs, whereby you let the value of i range from 1 to 9?

# %%
x = np.arange(20)

plt.figure(figsize=(10, 10))

for i in range(1, 9):
    plt.subplot(4, 2, i)
    y = np.arange(50, 70) + (np.random.random(20) * i)
    plt.plot(x, y)
    plt.title('Plot number {}'.format(i))
    
plt.tight_layout()
;
# Out:
# ''

# %% [markdown]
# Copyright © ASI 2017 All rights reserved
